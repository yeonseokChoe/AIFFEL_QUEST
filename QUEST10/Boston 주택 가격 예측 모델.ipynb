# %%
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras import callbacks

# %%
# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# 404
# 102

# %%
# 문제 1-1: 데이터셋의 전처리를 위해 표준화 작업을 수행합니다.
# 먼저 입력 데이터의 각 특성의 평균을 뺍니다.
mean = train_data.mean(axis=0)
train_data = train_data - mean

# 평균을 뺀 입력 데이터에서 표준편차를 나눕니다.
# 데이터 특성의 중앙이 0에 가깝게 만들고, 표준편차가 1이 되게 만듭니다.
std = train_data.std(axis=0)
train_data = train_data / std

# 테스트 데이터셋도 마찬가지로 평균을 빼고, 표준편차로 나눕니다.
test_data = test_data - mean
test_data = test_data / std

# %%
# 문제 1-2: 주택 가격 예측을 위한 딥러닝 모델 구성 및 컴파일합니다.
# input_shape은 (train_data.shape[1], )으로 구성합니다.
# 회귀(예측)을 위한 모델이므로 loss를 mse, metrics를 mae로 사용합니다.
model = models.Sequential()
model.add(layers.Input(shape=(train_data.shape[1], )))
model.add(layers.Dense(13, activation='relu'))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1, activation='relu'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 13)                182
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                896
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,143
# Trainable params: 1,143
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='mse', optimizer='adam', metrics=['mae'])

# %%
check_point_cb = callbacks.ModelCheckpoint('fashion_mnist_model.h5', 
                                           save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=10, 
                                            monitor='val_loss',
                                            restore_best_weights=True)

# %%
# 문제 1-3: 예측을 위한 딥러닝 모델을 학습합니다.
history = model.fit(train_data, train_labels,
                    epochs=100,
                    validation_data=(test_data, test_labels),
                   callbacks=[check_point_cb, early_stopping_cb])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 14ms/step - loss: 560.1313 - mae: 21.8342 - val_loss: 573.3098 - val_mae: 22.1881
# Epoch 2/100
# 13/13 [==============================] - 0s 4ms/step - loss: 532.9852 - mae: 21.2400 - val_loss: 542.0981 - val_mae: 21.5123
# Epoch 3/100
# 13/13 [==============================] - 0s 4ms/step - loss: 500.1885 - mae: 20.5000 - val_loss: 503.5784 - val_mae: 20.6582
# Epoch 4/100
# 13/13 [==============================] - 0s 4ms/step - loss: 459.6287 - mae: 19.5672 - val_loss: 454.1738 - val_mae: 19.5209
# Epoch 5/100
# 13/13 [==============================] - 0s 4ms/step - loss: 408.5785 - mae: 18.3260 - val_loss: 392.4946 - val_mae: 18.0375
# Epoch 6/100
# 13/13 [==============================] - 0s 4ms/step - loss: 344.3051 - mae: 16.7094 - val_loss: 318.4448 - val_mae: 16.1019
# Epoch 7/100
# 13/13 [==============================] - 0s 4ms/step - loss: 270.3930 - mae: 14.6178 - val_loss: 236.6723 - val_mae: 13.7344
# Epoch 8/100
# 13/13 [==============================] - 0s 4ms/step - loss: 193.3266 - mae: 12.1053 - val_loss: 160.0464 - val_mae: 10.9746
# Epoch 9/100
# 13/13 [==============================] - 0s 4ms/step - loss: 128.4886 - mae: 9.4383 - val_loss: 101.5265 - val_mae: 8.4213
# Epoch 10/100
# 13/13 [==============================] - 0s 4ms/step - loss: 84.7826 - mae: 7.2303 - val_loss: 69.0321 - val_mae: 6.6970
# Epoch 11/100
# 13/13 [==============================] - 0s 4ms/step - loss: 63.0117 - mae: 6.0070 - val_loss: 55.6528 - val_mae: 5.9331
# Epoch 12/100
# 13/13 [==============================] - 0s 4ms/step - loss: 53.7387 - mae: 5.4792 - val_loss: 49.4284 - val_mae: 5.6736
# Epoch 13/100
# 13/13 [==============================] - 0s 4ms/step - loss: 48.1990 - mae: 5.1771 - val_loss: 45.2710 - val_mae: 5.4546
# Epoch 14/100
# 13/13 [==============================] - 0s 4ms/step - loss: 43.8228 - mae: 4.9125 - val_loss: 42.3859 - val_mae: 5.2750
# Epoch 15/100
# 13/13 [==============================] - 0s 4ms/step - loss:
100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.6079 - mae: 2.8256 - val_loss: 26.0670 - val_mae: 3.6868
# Epoch 46/100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.3381 - mae: 2.8044 - val_loss: 26.1351 - val_mae: 3.6897
# Epoch 47/100
# 13/13 [==============================] - 0s 4ms/step - loss: 15.0605 - mae: 2.7823 - val_loss: 25.8603 - val_mae: 3.6605
# Epoch 48/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.8267 - mae: 2.7556 - val_loss: 25.8059 - val_mae: 3.6505
# Epoch 49/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.5826 - mae: 2.7346 - val_loss: 25.6323 - val_mae: 3.6236
# Epoch 50/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.3905 - mae: 2.7189 - val_loss: 25.7438 - val_mae: 3.6251
# Epoch 51/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.1470 - mae: 2.6984 - val_loss: 25.4462 - val_mae: 3.5972
# Epoch 52/100
# 13/13 [==============================] - 0s 4ms/step - loss: 14.0026 - mae: 2.6810 - val_loss: 25.1541 - val_mae: 3.5660
# Epoch 53/100
# 13/13 [==============================] - 0s 4ms/step - loss: 13.7563 - mae: 2.6651 - val_loss: 25.3820 - val_mae: 3.5675
# Epoch 54/100
# 13/13 [==============================] - 0s 4ms/step - loss: 13.5643 - mae: 2.6488 - val_loss: 25.3682 - val_mae: 3.5556
# Epoch 55/100
# 13/13 [==============================] - 0s 4ms/step - loss: 13.3911 - mae: 2.6348 - val_loss: 25.2162 - val_mae: 3.5329
# Epoch 56/100
# 13/13 [==============================] - 0s 4ms/step - loss: 13.2349 - mae: 2.6197 - val_loss: 25.0859 - val_mae: 3.5142
# Epoch 57/100
# 13/13 [==============================] - 0s 4ms/step - loss: 13.0885 - mae: 2.5951 - val_loss: 24.9766 - val_mae: 3.4938
# Epoch 58/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.9049 - mae: 2.5752 - val_loss: 24.9609 - val_mae: 3.4808
# Epoch 59/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.7753 - mae: 2.5766 - val_loss: 25.0366 - val_mae: 3.4746
# Epoch 60/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.5889 - mae: 2.5576 - val_loss: 24.8525 - val_mae: 3.4536
# Epoch 61/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.4469 - mae: 2.5431 - val_loss: 24.8641 - val_mae: 3.4455
# Epoch 62/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.3504 - mae: 2.5262 - val_loss: 24.8271 - val_mae: 3.4283
# Epoch 63/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.2055 - mae: 2.5184 - val_loss: 24.7089 - val_mae: 3.4131
# Epoch 64/100
# 13/13 [==============================] - 0s 4ms/step - loss: 12.0782 - mae: 2.5073 - val_loss: 24.6735 - val_mae: 3.4044
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 11.9389 - mae: 2.4879 - val_loss: 24.6149 - val_mae: 3.3884
# Epoch 66/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.7898 - mae: 2.4733 - val_loss: 24.4448 - val_mae: 3.3717
# Epoch 67/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.6604 - mae: 2.4570 - val_loss: 24.4116 - val_mae: 3.3679
# Epoch 68/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.5581 - mae: 2.4519 - val_loss: 24.5835 - val_mae: 3.3681
# Epoch 69/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.4273 - mae: 2.4436 - val_loss: 24.2531 - val_mae: 3.3435
# Epoch 70/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.3199 - mae: 2.4294 - val_loss: 24.4115 - val_mae: 3.3389
# Epoch 71/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.2301 - mae: 2.4160 - val_loss: 24.2761 - val_mae: 3.3280
# Epoch 72/100
# 13/13 [==============================] - 0s 4ms/step - loss: 11.1201 - mae: 2.4075 - val_loss: 24.3104 - val_mae: 3.3257
# Epoch 73/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.9943 - mae: 2.4006 - val_loss: 24.5193 - val_mae: 3.3288
# Epoch 74/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.9663 - mae: 2.4075 - val_loss: 24.3277 - val_mae: 3.3194
# Epoch 75/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.8414 - mae: 2.3812 - val_loss: 24.3261 - val_mae: 3.3157
# Epoch 76/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.7720 - mae: 2.3637 - val_loss: 24.1494 - val_mae: 3.2911
# Epoch 77/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.6883 - mae: 2.3553 - val_loss: 24.2614 - val_mae: 3.2938
# Epoch 78/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.5693 - mae: 2.3434 - val_loss: 24.1822 - val_mae: 3.2865
# Epoch 79/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.5237 - mae: 2.3426 - val_loss: 24.0461 - val_mae: 3.2695
# Epoch 80/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.4350 - mae: 2.3304 - val_loss: 23.9439 - val_mae: 3.2629
# Epoch 81/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.3774 - mae: 2.3180 - val_loss: 23.9392 - val_mae: 3.2594
# Epoch 82/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.3443 - mae: 2.3120 - val_loss: 23.6248 - val_mae: 3.2409
# Epoch 83/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.3047 - mae: 2.3251 - val_loss: 24.3146 - val_mae: 3.2629
# Epoch 84/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.1745 - mae: 2.3009 - val_loss: 23.8617 - val_mae: 3.2422
# Epoch 85/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0951 - mae: 2.2907 - val_loss: 23.9901 - val_mae: 3.2437
# Epoch 86/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0512 - mae: 2.2904 - val_loss: 24.0149 - val_mae: 3.2383
# Epoch 87/100
# 13/13 [==============================] - 0s 4ms/step - loss: 10.0666 - mae: 2.2792 - val_loss: 23.5957 - val_mae: 3.2137
# Epoch 88/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.9169 - mae: 2.2677 - val_loss: 24.1614 - val_mae: 3.2380
# Epoch 89/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8885 - mae: 2.2717 - val_loss: 24.0695 - val_mae: 3.2280
# Epoch 90/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.8280 - mae: 2.2707 - val_loss: 23.9681 - val_mae: 3.2247
# Epoch 91/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.7622 - mae: 2.2608 - val_loss: 23.6633 - val_mae: 3.1952
# Epoch 92/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6780 - mae: 2.2344 - val_loss: 23.5470 - val_mae: 3.1986
# Epoch 93/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6939 - mae: 2.2266 - val_loss: 23.3020 - val_mae: 3.1929
# Epoch 94/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.6047 - mae: 2.2223 - val_loss: 23.2622 - val_mae: 3.1698
# Epoch 95/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.5794 - mae: 2.2253 - val_loss: 23.3244 - val_mae: 3.1669
# Epoch 96/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.5602 - mae: 2.2372 - val_loss: 23.7172 - val_mae: 3.1869
# Epoch 97/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.5215 - mae: 2.2205 - val_loss: 23.1003 - val_mae: 3.1690
# Epoch 98/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.4495 - mae: 2.2094 - val_loss: 23.2606 - val_mae: 3.1596
# Epoch 99/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.4095 - mae: 2.2147 - val_loss: 23.1159 - val_mae: 3.1426
# Epoch 100/100
# 13/13 [==============================] - 0s 4ms/step - loss: 9.3634 - mae: 2.1990 - val_loss: 22.9992 - val_mae: 3.1545

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.
plt.style.use('seaborn-white')

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 문제 1-4: 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(test_data, test_labels)
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 22.9992 - mae: 3.1545
# [22.99919891357422, 3.15452241897583]
